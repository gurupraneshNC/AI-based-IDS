# %% [markdown]
# # AI-Based Network Intrusion Detection & Attack Classification
# ## CNN & LSTM (Multi-Class) – UNSW-NB15
#
# - Multi-class attack category prediction
# - Early Stopping

# %% [markdown]
# ## 1. Install & Import Libraries

# %%
# !pip install numpy pandas scikit-learn tensorflow matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in e:\programfiles\anaconda\lib\site-packages (2.3.5)
# Requirement already satisfied: pandas in e:\programfiles\anaconda\lib\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in e:\programfiles\anaconda\lib\site-packages (1.7.2)
# Requirement already satisfied: tensorflow in e:\programfiles\anaconda\lib\site-packages (2.20.0)
# Requirement already satisfied: matplotlib in e:\programfiles\anaconda\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in e:\programfiles\anaconda\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\programfiles\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\programfiles\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\programfiles\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in e:\programfiles\anaconda\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in e:\programfiles\anaconda\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\programfiles\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: h5py>=3.11.0 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in e:\programfiles\anaconda\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\programfiles\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\programfiles\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\programfiles\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\programfiles\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in e:\programfiles\anaconda\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in e:\programfiles\anaconda\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in e:\programfiles\anaconda\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\programfiles\anaconda\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in e:\programfiles\anaconda\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in e:\programfiles\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\programfiles\anaconda\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\programfiles\anaconda\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\programfiles\anaconda\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in e:\programfiles\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in e:\programfiles\anaconda\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in e:\programfiles\anaconda\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in e:\programfiles\anaconda\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\programfiles\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\programfiles\anaconda\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\programfiles\anaconda\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in e:\programfiles\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## 2. Load Dataset

# %%
TEST_PATH = r"data/UNSW_NB15_testing-set(in).csv"
TRAIN_PATH  = r"data/UNSW_NB15_training-set(in).csv"

train_df = pd.read_csv(TRAIN_PATH)
test_df  = pd.read_csv(TEST_PATH)

train_df.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0   1  0.000011   udp       -   INT      2      0     496       0
# 1   2  0.000008   udp       -   INT      2      0    1762       0
# 2   3  0.000005   udp       -   INT      2      0    1068       0
# 3   4  0.000006   udp       -   INT      2      0     900       0
# 4   5  0.000010   udp       -   INT      2      0    2126       0
#
#           rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0   90909.0902  ...                 1               2             0
# 1  125000.0003  ...                 1               2             0
# 2  200000.0051  ...                 1               3             0
# 3  166666.6608  ...                 1               3             0
# 4  100000.0025  ...                 1               3             0
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0           0                 0           1           2                0
# 1           0                 0           1           2                0
# 2           0                 0           1           3                0
# 3           0                 0           2           3                0
# 4           0                 0           2           3                0
#
#    attack_cat  label
# 0      Normal      0
# 1      Normal      0
# 2      Normal      0
# 3      Normal      0
# 4      Normal      0
#
# [5 rows x 45 columns]

# %% [markdown]
# ## 3. Exploratory Data Analysis & Data Representation

# %% [markdown]
# ### 3.1 Attack Category Distribution

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=train_df['attack_cat'])
plt.xticks(rotation=45)
plt.title("Distribution of Attack Categories")
plt.xlabel("Attack Category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### 3.3 Feature Correlation Heatmap

# %%
numeric_df = train_df.select_dtypes(include=['int64', 'float64'])
corr = numeric_df.iloc[:, :25].corr()

plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap='coolwarm', linewidths=0.4)
plt.title("Correlation Heatmap of Network Traffic Features")
plt.show()

# %% [markdown]
# ### 3.4 Feature Behavior vs Attack Type

# %%
features_to_plot = ['dur', 'sbytes', 'dbytes']

for feature in features_to_plot:
    plt.figure(figsize=(7,4))
    sns.boxplot(x=train_df['attack_cat'], y=train_df[feature])
    plt.xticks(rotation=45)
    plt.title(f"{feature} distribution across attack categories")
    plt.show()

# %% [markdown]
# ## 4. Encode Categorical Features

# %%
categorical_cols = train_df.select_dtypes(include=['object']).columns
categorical_cols = categorical_cols.drop('attack_cat')

encoders = {}

for col in categorical_cols:
    le = LabelEncoder()
    combined = pd.concat([train_df[col], test_df[col]])
    le.fit(combined)

    train_df[col] = le.transform(train_df[col])
    test_df[col]  = le.transform(test_df[col])

    encoders[col] = le

# %% [markdown]
# ## 5. Encode Attack Categories

# %%
attack_encoder = LabelEncoder()

y_train = attack_encoder.fit_transform(train_df['attack_cat'])
y_test  = attack_encoder.transform(test_df['attack_cat'])

num_classes = len(attack_encoder.classes_)

y_train_cat = to_categorical(y_train, num_classes)
y_test_cat  = to_categorical(y_test, num_classes)

# %% [markdown]
# ## 6. Feature Scaling

# %%
X_train = train_df.drop(columns=['label', 'attack_cat'])
X_test  = test_df.drop(columns=['label', 'attack_cat'])

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

X_train_np = np.asarray(X_train)
X_test_np  = np.asarray(X_test)

# %% [markdown]
# ## 7. Handle Class Imbalance

# %%
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)

class_weight = dict(enumerate(class_weights))
class_weight
# Out:
# {0: np.float64(12.161299852289513),
#  1: np.float64(14.1221269296741),
#  2: np.float64(2.013499633162142),
#  3: np.float64(0.739597556593604),
#  4: np.float64(1.3581656219069613),
#  5: np.float64(0.4362884849769488),
#  6: np.float64(0.22251891891891892),
#  7: np.float64(2.3550343249427916),
#  8: np.float64(21.78095238095238),
#  9: np.float64(187.11818181818182)}

# %% [markdown]
# ## 8. CNN Model (Multi-Class)

# %%
X_train_cnn = X_train_np.reshape(X_train_np.shape[0], X_train_np.shape[1], 1)
X_test_cnn  = X_test_np.reshape(X_test_np.shape[0], X_test_np.shape[1], 1)

cnn_model = Sequential([
    Conv1D(64, 3, activation='relu', input_shape=(X_train_cnn.shape[1], 1)),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.3),

    Conv1D(128, 3, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(2),
    Dropout(0.3),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.4),
    Dense(num_classes, activation='softmax')
])

cnn_model.compile(
    optimizer=Adam(0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

cnn_model.fit(
    X_train_cnn,
    y_train_cat,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weight,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# E:\ProgramFiles\Anaconda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.6433 - loss: 2.1364 - val_accuracy: 0.0779 - val_loss: 4.1950
# Epoch 2/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6883 - loss: 1.7547 - val_accuracy: 0.1102 - val_loss: 4.1690
# Epoch 3/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7007 - loss: 1.6266 - val_accuracy: 0.1430 - val_loss: 3.2781
# Epoch 4/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7058 - loss: 1.5517 - val_accuracy: 0.1318 - val_loss: 3.2382
# Epoch 5/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7123 - loss: 1.5113 - val_accuracy: 0.1598 - val_loss: 3.1819
# Epoch 6/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7193 - loss: 1.4479 - val_accuracy: 0.2047 - val_loss: 3.1717
# Epoch 7/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7205 - loss: 1.4232 - val_accuracy: 0.1329 - val_loss: 3.4276
# Epoch 8/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7253 - loss: 1.4065 - val_accuracy: 0.2064 - val_loss: 2.6172
# Epoch 9/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.7251 - loss: 1.3807 - val_accuracy: 0.2144 - val_loss: 2.6242
# Epoch 10/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.7320 - loss: 1.4105 - val_accuracy: 0.1847 - val_loss: 3.0425
# Epoch 11/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7340 - loss: 1.3749 - val_accuracy: 0.2167 - val_loss: 2.6791
# Epoch 12/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7359 - loss: 1.3619 - val_accuracy: 0.2362 - val_loss: 2.7956
# Epoch 13/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.7374 - loss: 1.3386 - val_accuracy: 0.2251 - val_loss: 3.2835

# %%
cnn_pred = cnn_model.predict(X_test_cnn).argmax(axis=1)
print(classification_report(y_test, cnn_pred, target_names=attack_encoder.classes_))
# Out:
# 5480/5480 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step
#                 precision    recall  f1-score   support
#
#       Analysis       0.05      0.40      0.09      2000
#       Backdoor       0.04      0.16      0.07      1746
#            DoS       0.26      0.16      0.20     12264
#       Exploits       0.79      0.40      0.53     33393
#        Fuzzers       0.54      0.72      0.62     18184
#        Generic       1.00      0.98      0.99     40000
#         Normal       0.99      0.79      0.88     56000
# Reconnaissance       0.49      0.34      0.40     10491
#      Shellcode       0.10      0.69      0.18      1133
#          Worms       0.02      0.83      0.03       130
#
#       accuracy                           0.67    175341
#      macro avg       0.43      0.55      0.40    175341
#   weighted avg       0.80      0.67      0.71    175341

# %% [markdown]
# ## 9. LSTM Model (Multi-Class)

# %%
X_train_lstm = X_train_np.reshape(X_train_np.shape[0], 1, X_train_np.shape[1])
X_test_lstm  = X_test_np.reshape(X_test_np.shape[0], 1, X_test_np.shape[1])

lstm_model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(1, X_train_np.shape[1])),
    Dropout(0.3),
    LSTM(128),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

lstm_model.compile(
    optimizer=Adam(0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

lstm_model.fit(
    X_train_lstm,
    y_train_cat,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    class_weight=class_weight,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# E:\ProgramFiles\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.6240 - loss: 1.9152 - val_accuracy: 0.0370 - val_loss: 4.4099
# Epoch 2/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7180 - loss: 1.4852 - val_accuracy: 0.0450 - val_loss: 3.9755
# Epoch 3/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7267 - loss: 1.4018 - val_accuracy: 0.0791 - val_loss: 3.4692
# Epoch 4/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7363 - loss: 1.3447 - val_accuracy: 0.1122 - val_loss: 3.3790
# Epoch 5/50
# 515/515 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7408 - loss: 1.3094 - val_accuracy: 0.1215 - val_loss: 3.3561

# %%
lstm_pred = lstm_model.predict(X_test_lstm).argmax(axis=1)
print(classification_report(y_test, lstm_pred, target_names=attack_encoder.classes_))
# Out:
# 5480/5480 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step
#                 precision    recall  f1-score   support
#
#       Analysis       0.05      0.06      0.06      2000
#       Backdoor       0.04      0.47      0.08      1746
#            DoS       0.15      0.01      0.01     12264
#       Exploits       0.78      0.40      0.53     33393
#        Fuzzers       0.44      0.69      0.54     18184
#        Generic       0.80      0.98      0.88     40000
#         Normal       0.99      0.75      0.86     56000
# Reconnaissance       0.11      0.01      0.02     10491
#      Shellcode       0.06      0.38      0.10      1133
#          Worms       0.01      0.79      0.03       130
#
#       accuracy                           0.62    175341
#      macro avg       0.34      0.45      0.31    175341
#   weighted avg       0.71      0.62      0.63    175341

# %% [markdown]
# ## 10. Saving Models

# %%
cnn_model.save("cnnmulti.keras")

# %%
lstm_model.save("lstm_multi.keras")
